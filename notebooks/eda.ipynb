# %%
import numpy as np
import pandas as pd

# %%
product1 = pd.read_csv("../data/processed/en_product1.csv")
product4 = pd.read_csv("../data/processed/en_product4.csv")
product6 = pd.read_csv("../data/processed/en_product6.csv")
product7 = pd.read_csv("../data/processed/en_product7.csv")
hp = pd.read_csv("../data/processed/hp.csv") 
phenotype = pd.read_csv("../data/processed/phenotype.csv")
# Out:
# /tmp/ipykernel_1225256/1745810329.py:6: DtypeWarning: Columns (2,6,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   phenotype = pd.read_csv("../data/processed/phenotype.csv")  # parsed phenotype.hpoa

# %%
datasets = {
    "product1": product1,
    "product4": product4,
    "product6": product6,
    "product7": product7,
    "hp": hp,
    "phenotype": phenotype
}

# %%
for name, df in datasets.items():
    print(f"\n--- {name} ---")
    print(f"Shape: {df.shape}") 
    print("Columns:", df.columns.tolist())
    print(df.head(3))  
    print(df.info())
    print("Missing values per column:\n", df.isnull().sum())
    print("="*50)
# Out:
# --- product1 ---
# Shape: (11239, 9)
# Columns: ['id', 'OrphaCode', 'Name', 'ExpertLink', 'Synonyms', 'DisorderType', 'DisorderGroup', 'ExternalReferences', 'Definition']
#       id  OrphaCode                                               Name  \
# 0  17601     166024  Multiple epiphyseal dysplasia-macrocephaly-fac...
# 1      2         58                                  Alexander disease
# 2  17603     166032  Multiple epiphyseal dysplasia-miniepiphyses sy...
#
#                                           ExpertLink  \
# 0  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...
# 1  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...
# 2  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...
#
#                                         Synonyms DisorderType DisorderGroup  \
# 0  Multiple epiphyseal dysplasia, Al-Gazali type      Disease      Disorder
# 1                                            AxD      Disease      Disorder
# 2                                            NaN      Disease      Disorder
#
#                                   ExternalReferences  \
# 0  ICD-11:LD24.61; MONDO:0011778; ICD-10:Q77.3; O...
# 1  OMIM:203450; MeSH:D038261; UMLS:C0270726; ICD-...
# 2  MeSH:C563735; MONDO:0012254; ICD-11:LD24.61; U...
#
#                                           Definition
# 0  A rare primary bone dysplasia characterized by...
# 1  A rare neurodegenerative disorder of the astro...
# 2  Multiple epiphyseal dysplasia, with miniepiphy...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11239 entries, 0 to 11238
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  11239 non-null  int64
#  1   OrphaCode           11239 non-null  int64
#  2   Name                11239 non-null  object
#  3   ExpertLink          11239 non-null  object
#  4   Synonyms            6906 non-null   object
#  5   DisorderType        11239 non-null  object
#  6   DisorderGroup       11239 non-null  object
#  7   ExternalReferences  9937 non-null   object
#  8   Definition          10634 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 790.4+ KB
# None
# Missing values per column:
#  id                       0
# OrphaCode                0
# Name                     0
# ExpertLink               0
# Synonyms              4333
# DisorderType             0
# DisorderGroup            0
# ExternalReferences    1302
# Definition             605
# dtype: int64
# ==================================================
#
# --- product4 ---
# Shape: (115627, 9)
# Columns: ['OrphaCode', 'DisorderName', 'ExpertLink', 'DisorderType', 'DisorderGroup', 'HPOId', 'HPOTerm', 'Frequency', 'DiagnosticCriteria']
#    OrphaCode       DisorderName  \
# 0         58  Alexander disease
# 1         58  Alexander disease
# 2         58  Alexander disease
#
#                                           ExpertLink DisorderType  \
# 0  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...      Disease
# 1  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...      Disease
# 2  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...      Disease
#
#   DisorderGroup       HPOId                  HPOTerm               Frequency  \
# 0      Disorder  HP:0000256             Macrocephaly  Very frequent (99-80%)
# 1      Disorder  HP:0001249  Intellectual disability  Very frequent (99-80%)
# 2      Disorder  HP:0001250                  Seizure  Very frequent (99-80%)
#
#   DiagnosticCriteria
# 0                 No
# 1                 No
# 2                 No
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115627 entries, 0 to 115626
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   OrphaCode           115627 non-null  int64
#  1   DisorderName        115627 non-null  object
#  2   ExpertLink          115627 non-null  object
#  3   DisorderType        115627 non-null  object
#  4   DisorderGroup       115627 non-null  object
#  5   HPOId               115627 non-null  object
#  6   HPOTerm             115627 non-null  object
#  7   Frequency           115627 non-null  object
#  8   DiagnosticCriteria  115627 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 7.9+ MB
# None
# Missing values per column:
#  OrphaCode             0
# DisorderName          0
# ExpertLink            0
# DisorderType          0
# DisorderGroup         0
# HPOId                 0
# HPOTerm               0
# Frequency             0
# DiagnosticCriteria    0
# dtype: int64
# ==================================================
#
# --- product6 ---
# Shape: (8300, 23)
# Columns: ['DisorderID', 'OrphaCode', 'DisorderName', 'ExpertLink', 'DisorderType', 'DisorderGroup', 'SourceOfValidation', 'AssociationType', 'AssociationStatus', 'GeneID', 'GeneName', 'GeneSymbol', 'GeneSynonyms', 'GeneType', 'GeneLocus', 'LocusKey', 'Ref_HGNC', 'Ref_Ensembl', 'Ref_OMIM', 'Ref_SwissProt', 'Ref_Genatlas', 'Ref_ClinVar', 'Ref_Reactome']
#    DisorderID  OrphaCode                                       DisorderName  \
# 0       17601     166024  Multiple epiphyseal dysplasia-macrocephaly-fac...
# 1           5         93                             Aspartylglucosaminuria
# 2       17604     166035  Brachydactyly-short stature-retinitis pigmento...
#
#                                           ExpertLink           DisorderType  \
# 0  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...                Disease
# 1  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...                Disease
# 2  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...  Malformation syndrome
#
#   DisorderGroup SourceOfValidation                          AssociationType  \
# 0      Disorder     22587682[PMID]  Disease-causing germline mutation(s) in
# 1      Disorder     11309371[PMID]  Disease-causing germline mutation(s) in
# 2      Disorder     28285769[PMID]  Disease-causing germline mutation(s) in
#
#   AssociationStatus  GeneID  ...                   GeneType GeneLocus  \
# 0          Assessed   20160  ...  gene with protein product   15q26.1
# 1          Assessed   15470  ...  gene with protein product    4q34.3
# 2          Assessed   26792  ...  gene with protein product    5q12.3
#
#   LocusKey Ref_HGNC      Ref_Ensembl  Ref_OMIM  Ref_SwissProt Ref_Genatlas  \
# 0        1  30497.0  ENSG00000166813  611254.0         Q2M1P5         KIF7
# 1        1    318.0  ENSG00000038002  613228.0         P20933          AGA
# 2        1  10664.0  ENSG00000153015  617170.0         Q6UX04          NaN
#
#    Ref_ClinVar Ref_Reactome
# 0         KIF7       Q2M1P5
# 1          AGA       P20933
# 2          NaN          NaN
#
# [3 rows x 23 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8300 entries, 0 to 8299
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DisorderID          8300 non-null   int64
#  1   OrphaCode           8300 non-null   int64
#  2   DisorderName        8300 non-null   object
#  3   ExpertLink          8300 non-null   object
#  4   DisorderType        8300 non-null   object
#  5   DisorderGroup       8300 non-null   object
#  6   SourceOfValidation  7554 non-null   object
#  7   AssociationType     8300 non-null   object
#  8   AssociationStatus   8300 non-null   object
#  9   GeneID              8300 non-null   int64
#  10  GeneName            8300 non-null   object
#  11  GeneSymbol          8300 non-null   object
#  12  GeneSynonyms        7411 non-null   object
#  13  GeneType            8300 non-null   object
#  14  GeneLocus           8300 non-null   object
#  15  LocusKey            8300 non-null   int64
#  16  Ref_HGNC            8298 non-null   float64
#  17  Ref_Ensembl         8240 non-null   object
#  18  Ref_OMIM            8247 non-null   float64
#  19  Ref_SwissProt       8171 non-null   object
#  20  Ref_Genatlas        7657 non-null   object
#  21  Ref_ClinVar         7657 non-null   object
#  22  Ref_Reactome        6620 non-null   object
# dtypes: float64(2), int64(4), object(17)
# memory usage: 1.5+ MB
# None
# Missing values per column:
#  DisorderID               0
# OrphaCode                0
# DisorderName             0
# ExpertLink               0
# DisorderType             0
# DisorderGroup            0
# SourceOfValidation     746
# AssociationType          0
# AssociationStatus        0
# GeneID                   0
# GeneName                 0
# GeneSymbol               0
# GeneSynonyms           889
# GeneType                 0
# GeneLocus                0
# LocusKey                 0
# Ref_HGNC                 2
# Ref_Ensembl             60
# Ref_OMIM                53
# Ref_SwissProt          129
# Ref_Genatlas           643
# Ref_ClinVar            643
# Ref_Reactome          1680
# dtype: int64
# ==================================================
#
# --- product7 ---
# Shape: (19506, 11)
# Columns: ['OrphaCode', 'DisorderName', 'ExpertLink', 'TotalAssociations', 'DisorderId', 'RootId', 'IsCycle', 'TargetId', 'TargetOrphaCode', 'TargetName', 'AssociationType']
#    OrphaCode                                       DisorderName  \
# 0     166024  Multiple epiphyseal dysplasia-macrocephaly-fac...
# 1         58                                  Alexander disease
# 2     166032  Multiple epiphyseal dysplasia-miniepiphyses sy...
#
#                                           ExpertLink  TotalAssociations  \
# 0  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...                  1
# 1  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...                  1
# 2  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...                  1
#
#    DisorderId  RootId  IsCycle  TargetId  TargetOrphaCode  \
# 0       17601   17601     True     12333          93419.0
# 1           2       2     True     13024          98006.0
# 2       17603   17603     True     12333          93419.0
#
#                 TargetName      AssociationType
# 0        Rare bone disease  Preferential parent
# 1  Rare neurologic disease  Preferential parent
# 2        Rare bone disease  Preferential parent
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19506 entries, 0 to 19505
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   OrphaCode          19506 non-null  int64
#  1   DisorderName       19506 non-null  object
#  2   ExpertLink         19506 non-null  object
#  3   TotalAssociations  19506 non-null  int64
#  4   DisorderId         19506 non-null  int64
#  5   RootId             19506 non-null  int64
#  6   IsCycle            19506 non-null  bool
#  7   TargetId           19506 non-null  int64
#  8   TargetOrphaCode    9753 non-null   float64
#  9   TargetName         9753 non-null   object
#  10  AssociationType    19506 non-null  object
# dtypes: bool(1), float64(1), int64(5), object(4)
# memory usage: 1.5+ MB
# None
# Missing values per column:
#  OrphaCode               0
# DisorderName            0
# ExpertLink              0
# TotalAssociations       0
# DisorderId              0
# RootId                  0
# IsCycle                 0
# TargetId                0
# TargetOrphaCode      9753
# TargetName           9753
# AssociationType         0
# dtype: int64
# ==================================================
#
# --- hp ---
# Shape: (19657, 11)
# Columns: ['id', 'name', 'definition', 'comment', 'synonyms', 'synonym_types', 'xrefs', 'alt_ids', 'is_a', 'created_date', 'obsolete']
#            id                          name  \
# 0  HP:0000001                           All
# 1  HP:0000002    Abnormality of body height
# 2  HP:0000003  Multicystic kidney dysplasia
#
#                                           definition  \
# 0                                                NaN
# 1  "Deviation from the norm of height with respec...
# 2  "Multicystic dysplasia of the kidney is charac...
#
#                                              comment  \
# 0  Root of all terms in the Human Phenotype Ontol...
# 1                                                NaN
# 2  Multicystic kidney dysplasia is the result of ...
#
#                                             synonyms        synonym_types  \
# 0                                                NaN                  NaN
# 1                         Abnormality of body height      EXACT layperson
# 2  Multicystic dysplastic kidney; Multicystic kid...  EXACT; EXACT; EXACT
#
#                                                xrefs     alt_ids  \
# 0                                      UMLS:C0444868         NaN
# 1                                      UMLS:C4025901         NaN
# 2  SNOMEDCT_US:204962002; SNOMEDCT_US:82525005; U...  HP:0004715
#
#                               is_a          created_date  obsolete
# 0                              NaN                   NaN     False
# 1  HP:0001507 ! Growth abnormality  2008-02-27T02:20:00Z     False
# 2          HP:0000107 ! Renal cyst                   NaN     False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19657 entries, 0 to 19656
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             19657 non-null  object
#  1   name           19657 non-null  object
#  2   definition     16624 non-null  object
#  3   comment        4348 non-null   object
#  4   synonyms       10942 non-null  object
#  5   synonym_types  10942 non-null  object
#  6   xrefs          11553 non-null  object
#  7   alt_ids        2053 non-null   object
#  8   is_a           19183 non-null  object
#  9   created_date   5011 non-null   object
#  10  obsolete       19657 non-null  bool
# dtypes: bool(1), object(10)
# memory usage: 1.5+ MB
# None
# Missing values per column:
#  id                   0
# name                 0
# definition        3033
# comment          15309
# synonyms          8715
# synonym_types     8715
# xrefs             8104
# alt_ids          17604
# is_a               474
# created_date     14646
# obsolete             0
# dtype: int64
# ==================================================
#
# --- phenotype ---
# Shape: (272726, 12)
# Columns: ['database_id', 'disease_name', 'qualifier', 'hpo_id', 'reference', 'evidence', 'onset', 'frequency', 'sex', 'modifier', 'aspect', 'biocuration']
#    database_id                                   disease_name qualifier  \
# 0  OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 1  OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 2  OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
#
#        hpo_id      reference evidence onset frequency  sex modifier aspect  \
# 0  HP:0011097  PMID:31675180      PCS   NaN       1/2  NaN      NaN      P
# 1  HP:0002187  PMID:31675180      PCS   NaN       1/1  NaN      NaN      P
# 2  HP:0001518  PMID:31675180      PCS   NaN       1/2  NaN      NaN      P
#
#                  biocuration
# 0  HPO:probinson[2021-06-21]
# 1  HPO:probinson[2021-06-21]
# 2  HPO:probinson[2021-06-21]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272726 entries, 0 to 272725
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   database_id   272726 non-null  object
#  1   disease_name  272726 non-null  object
#  2   qualifier     720 non-null     object
#  3   hpo_id        272726 non-null  object
#  4   reference     272726 non-null  object
#  5   evidence      272726 non-null  object
#  6   onset         3047 non-null    object
#  7   frequency     208493 non-null  object
#  8   sex           639 non-null     object
#  9   modifier      1021 non-null    object
#  10  aspect        272726 non-null  object
#  11  biocuration   272726 non-null  object
# dtypes: object(12)
# memory usage: 25.0+ MB
# None
# Missing values per column:
#  database_id          0
# disease_name         0
# qualifier       272006
# hpo_id               0
# reference            0
# evidence             0
# onset           269679
# frequency        64233
# sex             272087
# modifier        271705
# aspect               0
# biocuration          0
# dtype: int64
# ==================================================

# %%
# Overlap checks: HPO ids present in phenotype vs hp; OrphaCodes between product1 and product4/phenotype
results = {}
if 'hp' in datasets and 'phenotype' in datasets:
    hp_set = set(datasets['hp']['id'].dropna().unique())
    ph_set = set(datasets['phenotype']['hpo_id'].dropna().unique())
    results['hp_terms_in_phenotype'] = len(hp_set & ph_set)
    results['hp_terms_only_in_hp'] = len(hp_set - ph_set)
    results['hp_terms_only_in_phenotype'] = len(ph_set - hp_set)
if 'product1' in datasets and 'product4' in datasets:
    p1 = set(datasets['product1']['OrphaCode'].dropna().unique())
    p4 = set(datasets['product4']['OrphaCode'].dropna().unique())
    results['orpha_in_p1_p4_overlap'] = len(p1 & p4)
if 'product1' in datasets and 'phenotype' in datasets:
    p1 = set(datasets['product1']['OrphaCode'].dropna().unique())
    ph = set(datasets['phenotype']['database_id'].dropna().unique())
    results['orpha_in_p1_phenotype_overlap'] = len(p1 & ph)
results
# Out:
# {'hp_terms_in_phenotype': 11428,
#  'hp_terms_only_in_hp': 8229,
#  'hp_terms_only_in_phenotype': 0,
#  'orpha_in_p1_p4_overlap': 4314,
#  'orpha_in_p1_phenotype_overlap': 0}

# %%
summary_rows = []
for name, df in datasets.items():
    nrows, ncols = df.shape
    missing_total = int(df.isnull().sum().sum())
    dup = int(df.duplicated().sum())
    text_cols = [c for c in df.columns if any(k in c.lower() for k in ('name','term','def','definition','synonym','description','text'))]
    small_cardinal = {}
    for c in df.columns:
        nunique = df[c].nunique(dropna=True)
        if nunique <= 20:
            small_cardinal[c] = int(nunique)
    summary_rows.append({
        'dataset': name,
        'rows': nrows,
        'cols': ncols,
        'missing_values_total': missing_total,
        'duplicate_rows': dup,
        'text_columns_candidates': text_cols,
        'small_cardinalities_sample': small_cardinal,
        'columns': df.columns.tolist()
    })
summary_rows
# Out:
# [{'dataset': 'product1',
#   'rows': 11239,
#   'cols': 9,
#   'missing_values_total': 6240,
#   'duplicate_rows': 0,
#   'text_columns_candidates': ['Name', 'Synonyms', 'Definition'],
#   'small_cardinalities_sample': {'DisorderType': 11, 'DisorderGroup': 3},
#   'columns': ['id',
#    'OrphaCode',
#    'Name',
#    'ExpertLink',
#    'Synonyms',
#    'DisorderType',
#    'DisorderGroup',
#    'ExternalReferences',
#    'Definition']},
#  {'dataset': 'product4',
#   'rows': 115627,
#   'cols': 9,
#   'missing_values_total': 0,
#   'duplicate_rows': 1,
#   'text_columns_candidates': ['DisorderName', 'HPOTerm'],
#   'small_cardinalities_sample': {'DisorderType': 10,
#    'DisorderGroup': 3,
#    'Frequency': 6,
#    'DiagnosticCriteria': 1},
#   'columns': ['OrphaCode',
#    'DisorderName',
#    'ExpertLink',
#    'DisorderType',
#    'DisorderGroup',
#    'HPOId',
#    'HPOTerm',
#    'Frequency',
#    'DiagnosticCriteria']},
#  {'dataset': 'product6',
#   'rows': 8300,
#   'cols': 23,
#   'missing_values_total': 4845,
#   'duplicate_rows': 0,
#   'text_columns_candidates': ['DisorderName', 'GeneName', 'GeneSynonyms'],
#   'small_cardinalities_sample': {'DisorderType': 11,
#    'DisorderGroup': 3,
#    'AssociationType': 10,
#    'AssociationStatus': 2,
#    'GeneType': 3,
#    'LocusKey': 1},
#   'columns': ['DisorderID',
#    'OrphaCode',
#    'DisorderName',
#    'ExpertLink',
#    'DisorderType',
#    'DisorderGroup',
#    'SourceOfValidation',
#    'AssociationType',
#    'AssociationStatus',
#    'GeneID',
#    'GeneName',
#    'GeneSymbol',
#    'GeneSynonyms',
#    'GeneType',
#    'GeneLocus',
#    'LocusKey',
#    'Ref_HGNC',
#    'Ref_Ensembl',
#    'Ref_OMIM',
#    'Ref_SwissProt',
#    'Ref_Genatlas',
#    'Ref_ClinVar',
#    'Ref_Reactome']},
#  {'dataset': 'product7',
#   'rows': 19506,
#   'cols': 11,
#   'missing_values_total': 19506,
#   'duplicate_rows': 0,
#   'text_columns_candidates': ['DisorderName', 'TargetName'],
#   'small_cardinalities_sample': {'IsCycle': 2, 'AssociationType': 1},
#   'columns': ['OrphaCode',
#    'DisorderName',
#    'ExpertLink',
#    'TotalAssociations',
#    'DisorderId',
#    'RootId',
#    'IsCycle',
#    'TargetId',
#    'TargetOrphaCode',
#    'TargetName',
#    'AssociationType']},
#  {'dataset': 'hp',
#   'rows': 19657,
#   'cols': 11,
#   'missing_values_total': 76600,
#   'duplicate_rows': 0,
#   'text_columns_candidates': ['name',
#    'definition',
#    'synonyms',
#    'synonym_types'],
#   'small_cardinalities_sample': {'obsolete': 2},
#   'columns': ['id',
#    'name',
#    'definition',
#    'comment',
#    'synonyms',
#    'synonym_types',
#    'xrefs',
#    'alt_ids',
#    'is_a',
#    'created_date',
#    'obsolete']},
#  {'dataset': 'phenotype',
#   'rows': 272726,
#   'cols': 12,
#   'missing_values_total': 1149710,
#   'duplicate_rows': 45,
#   'text_columns_candidates': ['disease_name'],
#   'small_cardinalities_sample': {'qualifier': 1,
#    'evidence': 3,
#    'onset': 17,
#    'sex': 2,
#    'aspect': 5},
#   'columns': ['database_id',
#    'disease_name',
#    'qualifier',
#    'hpo_id',
#    'reference',
#    'evidence',
#    'onset',
#    'frequency',
#    'sex',
#    'modifier',
#    'aspect',
#    'biocuration']}]

# %%
# Count missing values column-wise
missing_by_col = product7.isnull().sum().sort_values(ascending=False)
print(missing_by_col)
# Out:
# TargetName           9753
# TargetOrphaCode      9753
# OrphaCode               0
# ExpertLink              0
# DisorderName            0
# TotalAssociations       0
# DisorderId              0
# IsCycle                 0
# RootId                  0
# TargetId                0
# AssociationType         0
# dtype: int64

# %%
for name,df in datasets.items():
    print("Columns:", df.columns.tolist())
# Out:
# Columns: ['id', 'OrphaCode', 'Name', 'ExpertLink', 'Synonyms', 'DisorderType', 'DisorderGroup', 'ExternalReferences', 'Definition']
# Columns: ['OrphaCode', 'DisorderName', 'ExpertLink', 'DisorderType', 'DisorderGroup', 'HPOId', 'HPOTerm', 'Frequency', 'DiagnosticCriteria']
# Columns: ['DisorderID', 'OrphaCode', 'DisorderName', 'ExpertLink', 'DisorderType', 'DisorderGroup', 'SourceOfValidation', 'AssociationType', 'AssociationStatus', 'GeneID', 'GeneName', 'GeneSymbol', 'GeneSynonyms', 'GeneType', 'GeneLocus', 'LocusKey', 'Ref_HGNC', 'Ref_Ensembl', 'Ref_OMIM', 'Ref_SwissProt', 'Ref_Genatlas', 'Ref_ClinVar', 'Ref_Reactome']
# Columns: ['OrphaCode', 'DisorderName', 'ExpertLink', 'TotalAssociations', 'DisorderId', 'RootId', 'IsCycle', 'TargetId', 'TargetOrphaCode', 'TargetName', 'AssociationType']
# Columns: ['id', 'name', 'definition', 'comment', 'synonyms', 'synonym_types', 'xrefs', 'alt_ids', 'is_a', 'created_date', 'obsolete']
# Columns: ['database_id', 'disease_name', 'qualifier', 'hpo_id', 'reference', 'evidence', 'onset', 'frequency', 'sex', 'modifier', 'aspect', 'biocuration']
